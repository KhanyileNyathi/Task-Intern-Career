# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Data.csv')

# %%
np.random.seed(123456)
df.head(70)
# Out:
#     Country          League   Club       Player Names  Matches_Played  \
# 0     Spain         La Liga  (BET)    Juanmi Callejon              19
# 1     Spain         La Liga  (BAR)  Antoine Griezmann              36
# 2     Spain         La Liga  (ATL)        Luis Suarez              34
# 3     Spain         La Liga  (CAR)       Ruben Castro              32
# 4     Spain         La Liga  (VAL)      Kevin Gameiro              21
# ..      ...             ...    ...                ...             ...
# 65  England  Premier League  (ROM)         Pedro None              26
# 66  England  Premier League  (RMA)        Eden Hazard              36
# 67  England  Premier League  (LIV)    Roberto Firmino              34
# 68  England  Premier League  (LIV)         Sadio Mane              26
# 69  England  Premier League  (BAR)  Philippe Coutinho              28
#
#     Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
df.shape
# Out:
# (660, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  660 non-null    object
#  1   League                   660 non-null    object
#  2   Club                     626 non-null    object
#  3   Player Names             660 non-null    object
#  4   Matches_Played           660 non-null    int64
#  5   Substitution             660 non-null    int64
#  6   Mins                     660 non-null    int64
#  7   Goals                    660 non-null    int64
#  8   xG                       660 non-null    float64
#  9   xG Per Avg Match         660 non-null    float64
#  10  Shots                    660 non-null    int64
#  11  OnTarget                 660 non-null    int64
#  12  Shots Per Avg Match      660 non-null    float64
#  13  On Target Per Avg Match  660 non-null    float64
# ...

# %%
type(df.Goals)
# Out:
# pandas.core.series.Series

# %%
plt.plot(df.Goals,df.Shots,'o')
plt.title('Goals and Shots')
plt.show()

# %%
#group for easy seperation by year
df['sep']=pd.cut(df['Year'],bins=5,labels=('2016','2017','2018','2019','2020'))
df
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie    NaN    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
#find the amount of goals scored each year
yearly_goals=df.groupby(['sep'])['Goals'].sum()
yearly_goals
# Out:
# sep
# 2016    1489
# 2017    1102
# 2018    1702
# 2019    2398
# 2020    1087
# Name: Goals, dtype: int64

# %%
plt.plot(df.sep ,df.Goals)
plt.plot(df.sep,df.Shots)
plt.plot(df.sep ,df.Mins)
plt.title('Stats for every year')
plt.legend(['Goals','Shots Taken','Minutes Played'])
plt.xlabel('Year')
plt.ylabel('Goals Scored per year')
plt.show()

# %%
#relative growth in goals scored
df.Goals/df.Goals.iloc[0]*100
# Out:
# 0      100.000000
# 1      145.454545
# 2      254.545455
# 3      118.181818
# 4      118.181818
#           ...
# 655     90.909091
# 656    109.090909
# 657     63.636364
# 658    136.363636
# 659     63.636364
# Name: Goals, Length: 660, dtype: float64

# %%
#compare the %
plt.plot(df.sep ,df.Goals/df.Goals.iloc[0]*100)
plt.plot(df.sep,df.Shots/df.Shots.iloc[0]*100)
plt.title('Percentage Goals And Shots Taken For Every Year')
plt.legend(['Goals','Shots Taken'])
plt.show()

# %%
df['Country'].value_counts()
# Out:
# Country
# Spain           100
# Italy           100
# Germany         100
# Brazil          100
# England          80
# France           60
# USA              40
# Portugal         40
#  Netherlands     40
# Name: count, dtype: int64

# %%
df.loc[[62,270]]
df['Player Names'] = pd.Series(df['Player Names'], dtype="float")
df
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie    NaN    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
df.describe()
# Out:
#        Matches_Played  Substitution          Mins       Goals          xG  \
# count      660.000000     660.000000   660.000000  660.000000  660.000000
# mean        22.371212       3.224242  2071.416667   11.784848   10.089606
# std          9.754658       3.839498   900.595049    5.982454    5.724844
# min          2.000000       0.000000   264.000000    2.000000    0.710000
# 25%         14.000000       0.000000  1363.500000    8.000000    6.100000
# 50%         24.000000       2.000000  2245.500000   11.000000    9.285000
# 75%         31.000000       5.000000  2822.000000   14.000000   13.252500
# max         38.000000      26.000000  4177.000000   37.000000   32.540000
#
#        xG Per Avg Match       Shots    OnTarget  Shots Per Avg Match  \
# count        660.000000  660.000000  660.000000           660.000000
# mean           0.476167   64.177273   28.365152             2.948015
# std            0.192831   34.941622   16.363149             0.914906
# ...

# %%
df.dropna(inplace=True)

# %%
df.dtypes
# Out:
# Country                      object
# League                       object
# Club                         object
# Player Names                 object
# Matches_Played                int64
# Substitution                  int64
# Mins                          int64
# Goals                         int64
# xG                          float64
# xG Per Avg Match            float64
# Shots                         int64
# OnTarget                      int64
# Shots Per Avg Match         float64
# On Target Per Avg Match     float64
# Year                          int64
# sep                        category
# dtype: object

# %%
df['League'].unique()
# Out:
# array(['La Liga', 'Serie A', 'Bundesliga', 'Premier League',
#        'Campeonato Brasileiro S̩rie A', 'France Ligue 11',
#        'France Ligue 20', 'France Ligue 2', 'France Ligue 12',
#        'France Ligue 9', 'France Ligue 15', 'France Ligue 6',
#        'France Ligue 3', 'France Ligue 16', 'France Ligue 14',
#        'France Ligue 4', 'France Ligue 1', 'France Ligue 10',
#        'France Ligue 7', 'France Ligue 13', 'France Ligue 8',
#        'France Ligue 5', 'France Ligue 19', 'France Ligue 18',
#        'France Ligue 17', 'MLS', 'Primeira Liga', 'Eredivisie'],
#       dtype=object)

# %%
df1 = df.drop(columns=['League'],inplace=True, axis=1)
df
# Out:
#           Country   Club       Player Names  Matches_Played  Substitution   \
# 0           Spain  (BET)    Juanmi Callejon              19             16
# 1           Spain  (BAR)  Antoine Griezmann              36              0
# 2           Spain  (ATL)        Luis Suarez              34              1
# 3           Spain  (CAR)       Ruben Castro              32              3
# 4           Spain  (VAL)      Kevin Gameiro              21             10
# ..            ...    ...                ...             ...            ...
# 654   Netherlands  (RZA)       Haris Vuckic              23              2
# 655   Netherlands  (UTR)        Gyrano Kerk              24              0
# 656   Netherlands  (AJA)      Quincy Promes              18              2
# 657   Netherlands  (PSV)    Denzel Dumfries              25              0
# 659   Netherlands  (PSV)         Cody Gakpo              14             11
#
#      Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
#save
df.to_excel("task2\new.xlsx" ,index=False)
